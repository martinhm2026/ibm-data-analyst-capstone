# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Line Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on using line charts to analyze trends over time and across different categories in a dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Track trends in compensation across age groups and specific age ranges.
#
# - Analyze job satisfaction trends based on experience level.
#
# - Explore and interpret line charts to identify patterns and trends.

# %% [markdown]
# ## Setup: Working with the Database
# **Install the needed libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %% [markdown]
# #### Step 1: Download the dataset

# %%
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Out:
# --2026-07-21 00:01:13--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  32.3MB/s    in 4.6s
#
# 2026-07-21 00:01:18 (32.8 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]

# %% [markdown]
# #### Step 2: Import necessary libraries and load the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load the data

# %%
df = pd.read_csv("survey-data.csv")

# %% [markdown]
# #### Display the first few rows to understand the structure of the data

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 1: Trends in Compensation Over Age Groups

# %% [markdown]
# ##### 1. Line Chart of Median `ConvertedCompYearly` by Age Group

# %% [markdown]
# - Track how the median yearly compensation (ConvertedCompYearly) changes across different age groups.
#
# - Use a line chart to visualize these trends.

# %%
## Write your code here
df_plot = (
    df[["Age", "ConvertedCompYearly"]]
    .dropna()
    .copy()
)

df_plot["ConvertedCompYearly"] = pd.to_numeric(
    df_plot["ConvertedCompYearly"],
    errors="coerce"
)

df_plot = (
    df_plot
    .dropna(subset=["ConvertedCompYearly"])
    .copy()
)

# %%
median_compensation_by_age = (
    df_plot
    .groupby("Age", as_index=False)["ConvertedCompYearly"]
    .median()
)

# %%
age_order = [
    "Under 18 years old",
    "18-24 years old",
    "25-34 years old",
    "35-44 years old",
    "45-54 years old",
    "55-64 years old",
    "65 years or older",
    "Prefer not to say"
]

median_compensation_by_age["Age"] = pd.Categorical(
    median_compensation_by_age["Age"],
    categories=age_order,
    ordered=True
)

median_compensation_by_age = (
    median_compensation_by_age
    .sort_values("Age")
    .dropna(subset=["Age"])
    .reset_index(drop=True)
)

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(
    median_compensation_by_age["Age"],
    median_compensation_by_age["ConvertedCompYearly"],
    marker="o",
    linewidth=2
)

ax.set_title(
    "Median Yearly Compensation by Age Group",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Age Group", fontsize=11)
ax.set_ylabel("Median Yearly Compensation (USD)", fontsize=11)

ax.yaxis.set_major_formatter(
    plt.FuncFormatter(lambda value, _: f"${value:,.0f}")
)

ax.grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)

plt.xticks(
    rotation=45,
    ha="right"
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2. Line Chart of Median `ConvertedCompYearly` for Ages 25 to 45

# %% [markdown]
# For a closer look, plot a line chart focusing on the median compensation for respondents between ages 25 and 45.

# %%
## Write your code here
target_age_groups = [
    "25-34 years old",
    "35-44 years old"
]

df_plot = (
    df.loc[
        df["Age"].isin(target_age_groups),
        ["Age", "ConvertedCompYearly"]
    ]
    .copy()
)

df_plot["ConvertedCompYearly"] = pd.to_numeric(
    df_plot["ConvertedCompYearly"],
    errors="coerce"
)

df_plot = (
    df_plot
    .dropna(subset=["ConvertedCompYearly"])
    .copy()
)

# %%
median_compensation_25_44 = (
    df_plot
    .groupby("Age", as_index=False, observed=True)
    .agg(
        MedianCompensation=("ConvertedCompYearly", "median"),
        RespondentCount=("ConvertedCompYearly", "count")
    )
)

median_compensation_25_44["Age"] = pd.Categorical(
    median_compensation_25_44["Age"],
    categories=target_age_groups,
    ordered=True
)

median_compensation_25_44 = (
    median_compensation_25_44
    .sort_values("Age")
    .reset_index(drop=True)
)

display(median_compensation_25_44)
# Out:
#                Age  MedianCompensation  RespondentCount
# 0  25-34 years old             59825.0            10369
# 1  35-44 years old             84796.0             6231

# %%
fig, ax = plt.subplots(figsize=(9, 5))

ax.plot(
    median_compensation_25_44["Age"],
    median_compensation_25_44["MedianCompensation"],
    marker="o",
    linewidth=2,
    markersize=8
)

ax.set_title(
    "Median Yearly Compensation for Respondents Aged 25–44",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Age Group", fontsize=11)
ax.set_ylabel("Median Yearly Compensation (USD)", fontsize=11)

ax.yaxis.set_major_formatter(
    plt.FuncFormatter(lambda value, _: f"${value:,.0f}")
)

ax.grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 2: Trends in Job Satisfaction by Experience Level

# %% [markdown]
# ##### 1. Line Chart of Job Satisfaction (`JobSatPoints_6`) by Experience Level

# %% [markdown]
# - Use a column that approximates experience level to analyze how job satisfaction changes with experience.
#
# - If needed, substitute an available experience-related column for `Experience`.

# %%
## Write your code here
df_plot = (
    df[["WorkExp", "JobSatPoints_6"]]
    .copy()
)

df_plot["WorkExp"] = pd.to_numeric(
    df_plot["WorkExp"],
    errors="coerce"
)

df_plot["JobSatPoints_6"] = pd.to_numeric(
    df_plot["JobSatPoints_6"],
    errors="coerce"
)

df_plot = (
    df_plot
    .dropna(subset=["WorkExp", "JobSatPoints_6"])
    .copy()
)

# %%
display(df_plot.describe())
# Out:
#             WorkExp  JobSatPoints_6
# count  29248.000000    29248.000000
# mean      11.478152       24.428258
# std        9.178948       27.079027
# min        0.000000        0.000000
# 25%        4.000000        0.000000
# 50%        9.000000       20.000000
# 75%       16.000000       30.000000
# max       50.000000      100.000000

# %%
job_satisfaction_by_experience = (
    df_plot
    .groupby("WorkExp", as_index=False)
    .agg(
        MedianJobSatisfaction=("JobSatPoints_6", "median"),
        RespondentCount=("JobSatPoints_6", "count")
    )
    .sort_values("WorkExp")
    .reset_index(drop=True)
)

display(job_satisfaction_by_experience)
# Out:
#     WorkExp  MedianJobSatisfaction  RespondentCount
# 0       0.0                    5.0              186
# 1       1.0                   10.0             1430
# 2       2.0                   15.0             1861
# 3       3.0                   20.0             2111
# 4       4.0                   20.0             1751
# 5       5.0                   20.0             2028
# 6       6.0                   20.0             1572
# 7       7.0                   20.0             1555
# 8       8.0                   20.0             1535
# 9       9.0                   20.0              971
# 10     10.0                   20.0             2006
# 11     11.0                   20.0              806
# 12     12.0                   20.0             1234
# 13     13.0                   20.0              729
# 14     14.0                   20.0              644
# 15     15.0                   18.0             1222
# 16     16.0                   20.0              595
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(
    job_satisfaction_by_experience["WorkExp"],
    job_satisfaction_by_experience["MedianJobSatisfaction"],
    marker="o",
    linewidth=2,
    markersize=5
)

ax.set_title(
    "Median Job Satisfaction by Work Experience",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Years of Work Experience", fontsize=11)
ax.set_ylabel("Median Job Satisfaction Points", fontsize=11)

ax.grid(
    axis="both",
    linestyle="--",
    alpha=0.3
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3: Trends in Job Satisfaction and Compensation by Experience

# %% [markdown]
# ##### 1.Line Chart of Median ConvertedCompYearly Over Experience Level
#
# - This line chart will track how median compensation (`ConvertedCompYearly`) changes with increasing experience.
#
# - Use a column such as `WorkExp` or another relevant experience-related column.

# %%
## Write your code here
df_plot = (
    df[["WorkExp", "ConvertedCompYearly"]]
    .copy()
)

df_plot["WorkExp"] = pd.to_numeric(
    df_plot["WorkExp"],
    errors="coerce"
)

df_plot["ConvertedCompYearly"] = pd.to_numeric(
    df_plot["ConvertedCompYearly"],
    errors="coerce"
)

df_plot = (
    df_plot
    .dropna(subset=["WorkExp", "ConvertedCompYearly"])
    .copy()
)

# %%
compensation_by_experience = (
    df_plot
    .groupby("WorkExp", as_index=False)
    .agg(
        MedianCompensation=("ConvertedCompYearly", "median"),
        RespondentCount=("ConvertedCompYearly", "count")
    )
    .sort_values("WorkExp")
    .reset_index(drop=True)
)

display(compensation_by_experience)
# Out:
#     WorkExp  MedianCompensation  RespondentCount
# 0       0.0             13306.0               83
# 1       1.0             20077.0              730
# 2       2.0             27968.5             1050
# 3       3.0             34896.0             1223
# 4       4.0             42962.0             1014
# 5       5.0             51624.0             1191
# 6       6.0             57140.0              913
# 7       7.0             64444.0              901
# 8       8.0             69814.0              876
# 9       9.0             73932.0              539
# 10     10.0             75000.0             1118
# 11     11.0             85000.0              471
# 12     12.0             81629.0              689
# 13     13.0             85348.5              418
# 14     14.0             85925.0              341
# 15     15.0             85925.0              640
# 16     16.0             92708.0              330
# 17     17.0             93000.0              343
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(
    compensation_by_experience["WorkExp"],
    compensation_by_experience["MedianCompensation"],
    marker="o",
    linewidth=2,
    markersize=5
)

ax.set_title(
    "Median Yearly Compensation by Work Experience",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Years of Work Experience", fontsize=11)
ax.set_ylabel("Median Yearly Compensation (USD)", fontsize=11)

ax.yaxis.set_major_formatter(
    plt.FuncFormatter(lambda value, _: f"${value:,.0f}")
)

ax.grid(
    axis="both",
    linestyle="--",
    alpha=0.3
)

plt.tight_layout()
plt.show()

# %%
compensation_by_experience[
    compensation_by_experience["RespondentCount"] < 30
]
# Out:
#     WorkExp  MedianCompensation  RespondentCount
# 37     37.0            128887.0               27
# 38     38.0            120000.0               28
# 39     39.0            101910.0               15
# 41     41.0            131000.0               20
# 42     42.0            135000.0               29
# 43     43.0            100914.5               18
# 44     44.0             97258.5               16
# 45     45.0            123334.0               22
# 46     46.0             96496.5                8
# 47     47.0            100000.0                1
# 48     48.0            110000.0                1
# 49     49.0            109959.5                2
# 50     50.0            136000.0               21

# %% [markdown]
# ##### 2.Line Chart of Job Satisfaction (`JobSatPoints_6`) Across Experience Levels
#
# - Create a line chart to explore trends in job satisfaction (`JobSatPoints_6`) based on experience level.
#
# - This chart will provide insight into how satisfaction correlates with experience over time

# %%
## Write your code here
df_plot = (
    df[["WorkExp", "JobSatPoints_6"]]
    .copy()
)

df_plot["WorkExp"] = pd.to_numeric(
    df_plot["WorkExp"],
    errors="coerce"
)

df_plot["JobSatPoints_6"] = pd.to_numeric(
    df_plot["JobSatPoints_6"],
    errors="coerce"
)

df_plot = (
    df_plot
    .dropna(subset=["WorkExp", "JobSatPoints_6"])
    .copy()
)
job_satisfaction_by_experience = (
    df_plot
    .groupby("WorkExp", as_index=False)
    .agg(
        MedianJobSatisfaction=("JobSatPoints_6", "median"),
        RespondentCount=("JobSatPoints_6", "count")
    )
    .sort_values("WorkExp")
    .reset_index(drop=True)
)

display(job_satisfaction_by_experience)
# Out:
#     WorkExp  MedianJobSatisfaction  RespondentCount
# 0       0.0                    5.0              186
# 1       1.0                   10.0             1430
# 2       2.0                   15.0             1861
# 3       3.0                   20.0             2111
# 4       4.0                   20.0             1751
# 5       5.0                   20.0             2028
# 6       6.0                   20.0             1572
# 7       7.0                   20.0             1555
# 8       8.0                   20.0             1535
# 9       9.0                   20.0              971
# 10     10.0                   20.0             2006
# 11     11.0                   20.0              806
# 12     12.0                   20.0             1234
# 13     13.0                   20.0              729
# 14     14.0                   20.0              644
# 15     15.0                   18.0             1222
# 16     16.0                   20.0              595
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(
    job_satisfaction_by_experience["WorkExp"],
    job_satisfaction_by_experience["MedianJobSatisfaction"],
    marker="o",
    linewidth=2,
    markersize=5
)

ax.set_title(
    "Median Job Satisfaction by Work Experience",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Years of Work Experience", fontsize=11)
ax.set_ylabel("Median Job Satisfaction (JobSatPoints_6)", fontsize=11)

ax.grid(
    axis="both",
    linestyle="--",
    alpha=0.3
)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Final Step: Review

# %% [markdown]
# In this lab, you focused on analyzing trends in compensation and job satisfaction, specifically exploring how these metrics change with age and experience levels using line charts.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you explored essential data visualization techniques with a focus on analyzing trends using line charts. You learned to:
#
# - Visualize the distribution of compensation across age groups to understand salary trends.
#
# - Track changes in median compensation over various experience levels, identifying how earnings progress with experience.
#
# - Examine trends in job satisfaction by experience, revealing how satisfaction varies throughout a developer's career.
#
# These analyses allow for a deeper understanding of how factors like age and experience influence job satisfaction and compensation. By using line charts, you gained insights into continuous data patterns, which are invaluable for interpreting professional trends in the developer community.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-10-16|1.1|Madhusudhan Moole|Updated lab|
# |2024-10-15|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
