# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Bar Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on visualizing data.
#
# The dataset will be provided to you in the form of an RDBMS.
#
# You will use SQL queries to extract the necessary data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data
#
# -   Visualize the relationship between two features
#
# -   Visualize the composition of data
#
# -   Visualize comparison of data

# %% [markdown]
# ## Setup: Working with the Database
# **Install the needed libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2026-07-21 00:05:59--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# 198.23.119.245ourses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)...
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  49.3MB/s    in 3.1s
#
# 2026-07-21 00:06:02 (49.3 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Distributions

# %% [markdown]
# ##### 1. Histogram of `ConvertedCompYearly`

# %% [markdown]
# Visualize the distribution of yearly compensation (`ConvertedCompYearly`) using a histogram.

# %%
## Write your code here
df_plot = (
    df[["ConvertedCompYearly"]]
    .copy()
)

df_plot["ConvertedCompYearly"] = pd.to_numeric(
    df_plot["ConvertedCompYearly"],
    errors="coerce"
)

df_plot = (
    df_plot
    .dropna()
    .copy()
)

fig, ax = plt.subplots(figsize=(10, 6))

ax.hist(
    df_plot["ConvertedCompYearly"],
    bins=30,
    edgecolor="black"
)

ax.set_title(
    "Distribution of Yearly Compensation",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Yearly Compensation (USD)", fontsize=11)
ax.set_ylabel("Number of Respondents", fontsize=11)

ax.grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)

ax.xaxis.set_major_formatter(
    plt.FuncFormatter(lambda value, _: f"${value:,.0f}")
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2. Box Plot of `Age`

# %% [markdown]
# Since `Age` is categorical in the dataset, convert it to numerical values for a box plot.

# %%
## Write your code here
import numpy as np
age_mapping = {
    "Under 18 years old": 17,
    "18-24 years old": 21,
    "25-34 years old": 30,
    "35-44 years old": 40,
    "45-54 years old": 50,
    "55-64 years old": 60,
    "65 years or older": 70,
    "Prefer not to say": np.nan
}

df_plot = (
    df[["Age"]]
    .copy()
)

df_plot["Age_numeric"] = (
    df_plot["Age"]
    .map(age_mapping)
)

df_plot = (
    df_plot
    .dropna(subset=["Age_numeric"])
)

# %%
fig, ax = plt.subplots(figsize=(6, 7))

ax.boxplot(
    df_plot["Age_numeric"],
    vert=True,
    patch_artist=True
)

ax.set_title(
    "Distribution of Respondent Age",
    fontsize=15,
    pad=15
)

ax.set_ylabel("Approximate Age (Years)", fontsize=11)

ax.grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5369/4033870078.py:3: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   ax.boxplot(

# %% [markdown]
# ### Task 2: Visualizing Relationships in Data

# %% [markdown]
# ##### 1. Scatter Plot of `Age_numeric` and `ConvertedCompYearly`

# %% [markdown]
# Explore the relationship between age and compensation.

# %%
## Write your code here
age_mapping = {
    "Under 18 years old": 17,
    "18-24 years old": 21,
    "25-34 years old": 30,
    "35-44 years old": 40,
    "45-54 years old": 50,
    "55-64 years old": 60,
    "65 years or older": 70,
    "Prefer not to say": np.nan
}

df_plot = (
    df[["Age", "ConvertedCompYearly"]]
    .copy()
)

df_plot["Age_numeric"] = (
    df_plot["Age"]
    .map(age_mapping)
)

df_plot["ConvertedCompYearly"] = pd.to_numeric(
    df_plot["ConvertedCompYearly"],
    errors="coerce"
)

df_plot = (
    df_plot
    .dropna(subset=["Age_numeric", "ConvertedCompYearly"])
    .copy()
)

fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(
    df_plot["Age_numeric"],
    df_plot["ConvertedCompYearly"],
    alpha=0.4,
    s=20
)

ax.set_title(
    "Age vs Yearly Compensation",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Approximate Age (Years)", fontsize=11)
ax.set_ylabel("Yearly Compensation (USD)", fontsize=11)

ax.yaxis.set_major_formatter(
    plt.FuncFormatter(lambda value, _: f"${value:,.0f}")
)

ax.grid(
    linestyle="--",
    alpha=0.3
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2. Bubble Plot of `ConvertedCompYearly` and `JobSatPoints_6` with `Age_numeric` as Bubble Size

# %% [markdown]
# Explore how compensation and job satisfaction are related, with age as the bubble size.

# %%
## Write your code here
age_mapping = {
    "Under 18 years old": 17,
    "18-24 years old": 21,
    "25-34 years old": 30,
    "35-44 years old": 40,
    "45-54 years old": 50,
    "55-64 years old": 60,
    "65 years or older": 70,
    "Prefer not to say": np.nan
}

df_plot = (
    df[["Age", "ConvertedCompYearly", "JobSatPoints_6"]]
    .copy()
)

df_plot["Age_numeric"] = df_plot["Age"].map(age_mapping)

df_plot["ConvertedCompYearly"] = pd.to_numeric(
    df_plot["ConvertedCompYearly"],
    errors="coerce"
)

df_plot["JobSatPoints_6"] = pd.to_numeric(
    df_plot["JobSatPoints_6"],
    errors="coerce"
)

df_plot = (
    df_plot
    .dropna(
        subset=[
            "Age_numeric",
            "ConvertedCompYearly",
            "JobSatPoints_6"
        ]
    )
    .copy()
)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(
    x=df_plot["ConvertedCompYearly"],
    y=df_plot["JobSatPoints_6"],
    s=df_plot["Age_numeric"] * 4,
    alpha=0.5
)

ax.set_title(
    "Compensation vs Job Satisfaction\nBubble Size Represents Age",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Yearly Compensation (USD)", fontsize=11)
ax.set_ylabel("Job Satisfaction (JobSatPoints_6)", fontsize=11)

ax.xaxis.set_major_formatter(
    plt.FuncFormatter(lambda value, _: f"${value:,.0f}")
)

ax.grid(
    linestyle="--",
    alpha=0.3
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3: Visualizing Composition of Data with Bar Charts

# %% [markdown]
# ##### 1. Horizontal Bar Chart of `MainBranch` Distribution

# %% [markdown]
# Visualize the distribution of respondents’ primary roles to understand their professional focus.

# %%
## Write your code here
main_branch_counts = (
    df["MainBranch"]
    .dropna()
    .value_counts()
    .sort_values(ascending=True)
)
fig, ax = plt.subplots(figsize=(11, 6))

bars = ax.barh(
    main_branch_counts.index,
    main_branch_counts.values
)

ax.set_title(
    "Distribution of Respondents by Primary Role",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Number of Respondents", fontsize=11)
ax.set_ylabel("Primary Role (MainBranch)", fontsize=11)

ax.grid(
    axis="x",
    linestyle="--",
    alpha=0.3
)

ax.bar_label(
    bars,
    fmt="%.0f",
    padding=4
)

ax.xaxis.set_major_formatter(
    plt.FuncFormatter(lambda value, _: f"{value:,.0f}")
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2. Vertical Bar Chart of Top 5 Programming Languages Respondents Want to Work With

# %% [markdown]
# Identify the most desired programming languages based on `LanguageWantToWorkWith`.

# %%
## Write your code here
language_counts = (
    df["LanguageWantToWorkWith"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
    .value_counts()
    .head(5)
)

fig, ax = plt.subplots(figsize=(10, 6))

bars = ax.bar(
    language_counts.index,
    language_counts.values
)

ax.set_title(
    "Top 5 Programming Languages Respondents Want to Work With",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Programming Language", fontsize=11)
ax.set_ylabel("Number of Mentions", fontsize=11)

ax.grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)

ax.bar_label(
    bars,
    fmt="%.0f",
    padding=4
)

ax.yaxis.set_major_formatter(
    plt.FuncFormatter(lambda value, _: f"{value:,.0f}")
)

plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3. Stacked Bar Chart of Median `JobSatPoints_6` and `JobSatPoints_7` by Age Group

# %% [markdown]
# Compare job satisfaction metrics across different age groups with a stacked bar chart.

# %%
## Write your code here
df_plot = (
    df[["Age", "JobSatPoints_6", "JobSatPoints_7"]]
    .copy()
)

df_plot["JobSatPoints_6"] = pd.to_numeric(
    df_plot["JobSatPoints_6"],
    errors="coerce"
)

df_plot["JobSatPoints_7"] = pd.to_numeric(
    df_plot["JobSatPoints_7"],
    errors="coerce"
)

df_plot = df_plot.dropna(
    subset=["Age", "JobSatPoints_6", "JobSatPoints_7"]
)

age_order = [
    "Under 18 years old",
    "18-24 years old",
    "25-34 years old",
    "35-44 years old",
    "45-54 years old",
    "55-64 years old",
    "65 years or older"
]

median_jobsat = (
    df_plot
    .groupby("Age")[["JobSatPoints_6", "JobSatPoints_7"]]
    .median()
    .reindex(age_order)
    .dropna(how="all")
)

fig, ax = plt.subplots(figsize=(11, 6))

ax.bar(
    median_jobsat.index,
    median_jobsat["JobSatPoints_6"],
    label="JobSatPoints_6"
)

ax.bar(
    median_jobsat.index,
    median_jobsat["JobSatPoints_7"],
    bottom=median_jobsat["JobSatPoints_6"],
    label="JobSatPoints_7"
)

ax.set_title(
    "Median Job Satisfaction by Age Group",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Age Group", fontsize=11)
ax.set_ylabel("Median Score", fontsize=11)

ax.grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)

ax.legend()

plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 4. Bar Chart of Database Popularity (`DatabaseHaveWorkedWith`)

# %% [markdown]
# Identify the most commonly used databases among respondents by visualizing `DatabaseHaveWorkedWith`.

# %%
## Write your code here
database_counts = (
    df["DatabaseHaveWorkedWith"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
    .value_counts()
    .head(10)
    .sort_values(ascending=True)
)
fig, ax = plt.subplots(figsize=(10, 7))

bars = ax.barh(
    database_counts.index,
    database_counts.values
)

ax.set_title(
    "Top 10 Most Popular Databases",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Number of Mentions", fontsize=11)
ax.set_ylabel("Database", fontsize=11)

ax.grid(
    axis="x",
    linestyle="--",
    alpha=0.3
)

ax.bar_label(
    bars,
    fmt="%.0f",
    padding=4
)

ax.xaxis.set_major_formatter(
    plt.FuncFormatter(lambda value, _: f"{value:,.0f}")
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 4: Visualizing Comparison of Data with Bar Charts

# %% [markdown]
# ##### 1. Grouped Bar Chart of Median `ConvertedCompYearly` for Different Age Groups

# %% [markdown]
# Compare median compensation across multiple age groups with a grouped bar chart.

# %%
## Write your code here
df_plot = (
    df[["Age", "ConvertedCompYearly"]]
    .copy()
)

df_plot["ConvertedCompYearly"] = pd.to_numeric(
    df_plot["ConvertedCompYearly"],
    errors="coerce"
)

df_plot = df_plot.dropna(
    subset=["Age", "ConvertedCompYearly"]
)

age_order = [
    "Under 18 years old",
    "18-24 years old",
    "25-34 years old",
    "35-44 years old",
    "45-54 years old",
    "55-64 years old",
    "65 years or older"
]

median_compensation = (
    df_plot
    .groupby("Age")["ConvertedCompYearly"]
    .median()
    .reindex(age_order)
    .dropna()
)

fig, ax = plt.subplots(figsize=(11, 6))

bars = ax.bar(
    median_compensation.index,
    median_compensation.values
)

ax.set_title(
    "Median Yearly Compensation by Age Group",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Age Group", fontsize=11)
ax.set_ylabel("Median Compensation (USD)", fontsize=11)

ax.yaxis.set_major_formatter(
    plt.FuncFormatter(lambda value, _: f"${value:,.0f}")
)

ax.grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)

ax.bar_label(
    bars,
    fmt="%.0f",
    padding=3
)

plt.xticks(rotation=25, ha="right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2. Bar Chart of Respondent Count by Country

# %% [markdown]
# Show the distribution of respondents by country to see which regions are most represented.

# %%
## Write your code here
country_counts = (
    df["Country"]
    .dropna()
    .value_counts()
    .head(10)
    .sort_values(ascending=True)
)

fig, ax = plt.subplots(figsize=(10, 7))

bars = ax.barh(
    country_counts.index,
    country_counts.values
)

ax.set_title(
    "Top 10 Countries by Number of Respondents",
    fontsize=15,
    pad=15
)

ax.set_xlabel("Number of Respondents", fontsize=11)
ax.set_ylabel("Country", fontsize=11)

ax.grid(
    axis="x",
    linestyle="--",
    alpha=0.3
)

ax.bar_label(
    bars,
    fmt="%.0f",
    padding=4
)

ax.xaxis.set_major_formatter(
    plt.FuncFormatter(lambda value, _: f"{value:,.0f}")
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Final Step: Review

# %% [markdown]
# This lab demonstrates how to create and interpret different types of bar charts, allowing you to analyze the composition, comparison, and distribution of categorical data in the Stack Overflow dataset, including main professional branches, programming language preferences, and compensation by age group. Bar charts effectively compare counts and median values across various categories.

# %% [markdown]
# ## Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create a horizontal bar chart to visualize the distribution of respondents' primary roles, helping to understand their professional focus.
# - Develop a vertical bar chart to identify the most desired programming languages based on the LanguageWantToWorkWith variable.
# - Use a stacked bar chart to compare job satisfaction metrics across different age groups.
# - Create a bar chart to visualize the most commonly used databases among respondents using the DatabaseHaveWorkedWith variable.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
